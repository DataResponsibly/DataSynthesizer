# %% [markdown]
# # Usage of DataSynthesizer
#
# Given a private dataset, DataSynthesizer can be used to generate a synthetic dataset for release to public. It infers the data types and domains for attributes in dataset. Histograms are used to model the distribution of each attribute. Synthetic dataset is sampled from the histograms or uniformly from the inferred domains.
#
# ## Data types
#  The DataSynthesizer currently supports 4 basic data types.
#
# | data type | example |
# |-----------|---------|
# | integer   | id, age, ...|
# | float     | score, rating, ...|
# | string    | first name, gender, ...|
# | datetime  | birthday, event time, ...|
#
# ## Data description format
#
# The domain of an attribute is as follows.
# - The "catagorical" indicates attributes with particular values, e.g., "gender", "nationality".
# - Domains are modeled by histograms, except noncategorical "string".
#
# |data type|categorical  |min             |max             |values             |probabilities      |values count      |missing rate|
# |---------|----------|----------------|----------------|-------------------|-------------------|------------------|------------|
# |int      |True/False|min             |max             |x-axis in histogram|y-axis in histogram|#bins in histogram|missing rate|
# |float    |True/False|min             |max             |x-axis in histogram|y-axis in histogram|#bins in histogram|missing rate|
# |string   |   True   |min in length   |max in length   |x-axis in histogram|y-axis in histogram|#bins in histogram|missing rate|
# |string   |   False  |min in length   |max in length   |0                  |0                  |0               |missing rate|
# |datetime |True/False|min in timestamp|max in timestamp|x-axis in histogram|y-axis in histogram|#bins in histogram|missing rate|

# %% [markdown]
# ##### Step 0: Import DataDestriber and DataGenerator from DataSynthesizer

# %%
from DataSynthesizer import DataDestriber, DataGenerator

# %%
# Directories of input and output files
input_dataset_file = './raw_data/AdultIncomeData/adult.csv'
dataset_description_file = './output/description/AdultIncomeData_description.csv'
synthetic_data_file = './output/synthetic_data/AdultIncomeData_synthetic.csv'

# %% [markdown]
# ##### Step 1: Initialize a DatasetDescriber

# %%
describer = DataDestriber()
# Out:
# Initialized a dataset describer.

# %% [markdown]
# ##### Step 1: Generate dataset description
#
# The dataset description is inferred by code, which also allows users to customize the data types and categorical indicators, e.g.,
#     - "education-num" is of type "float".
#     - "native-country" is not categrocial.
#     - "age" is categorical.

# %%
describer.describe_dataset(file_name=input_dataset_file,
                           column_to_datatype_dict={'education-num': 'float'},
                           column_to_categorical_dict={'native-country':False,'age':True})

# %% [markdown]
# ##### Step 2: Get the dataset description
#
# Let's take a look at the input dataset

# %%
describer.input_dataset.head()
# Out:
#     ID   age          workclass    fnlwgt   education  education-num  \
# 0  1.0  39.0          State-gov   77516.0   Bachelors           13.0
# 1  2.0  50.0   Self-emp-not-inc   83311.0   Bachelors            NaN
# 2  3.0  38.0            Private  215646.0     HS-grad            9.0
# 3  4.0  53.0                NaN  234721.0        11th            7.0
# 4  5.0  28.0                NaN       NaN   Bachelors            NaN
#
#         marital-status          occupation relationship    race      sex  \
# 0        Never-married        Adm-clerical          NaN   White     Male
# 1                  NaN                 NaN      Husband   White      NaN
# 2             Divorced                 NaN          NaN   White     Male
# 3   Married-civ-spouse   Handlers-cleaners      Husband   Black     Male
# 4                  NaN                 NaN          NaN   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0        2174.0           NaN            40.0   United-States   <=50K
# 1           0.0           0.0            13.0   United-States     NaN
# 2           NaN           NaN             NaN   United-States   <=50K
# 3           0.0           0.0            40.0   United-States   <=50K
# 4           0.0           NaN            40.0            Cuba     NaN

# %% [markdown]
# The dataset description is

# %%
describer.dataset_description
# Out:
#                data type categorical      min        max  \
# column
# ID                   int       False      1.0    32561.0
# age                  int        True     17.0       90.0
# workclass         string        True      2.0       17.0
# fnlwgt               int       False  12285.0  1455435.0
# education         string        True      4.0       13.0
# education-num      float        True      1.0       16.0
# marital-status    string        True      8.0       22.0
# occupation        string        True      2.0       18.0
# relationship      string        True      5.0       15.0
# race              string        True      6.0       19.0
# sex               string        True      5.0        7.0
# capital-gain         int       False      0.0    99999.0
# capital-loss         int       False      0.0     4356.0
# hours-per-week       int       False      1.0       99.0
# native-country    string       False      2.0       27.0
# income            string        True      5.0        6.0
#
#                                                            values  \
# column
# ID              [14653.0, 29305.0, 30933.0, 4885.0, 8141.0, 32...
# age             [36.0, 35.0, 31.0, 33.0, 34.0, 23.0, 28.0, 37....
# workclass       [ Private,  Self-emp-not-inc,  Local-gov,  ?, ...
# fnlwgt          [156600.0, 84442.5, 228757.5, 10841.85, 300915...
# education       [ HS-grad,  Some-college,  Bachelors,  Masters...
# education-num   [9.0, 10.0, 13.0, 14.0, 11.0, 7.0, 12.0, 6.0, ...
# marital-status  [ Married-civ-spouse,  Never-married,  Divorce...
# occupation      [ Craft-repair,  Exec-managerial,  Prof-specia...
# relationship    [ Husband,  Not-in-family,  Own-child,  Unmarr...
# race            [ White,  Black,  Asian-Pac-Islander,  Amer-In...
# sex                                              [ Male,  Female]
# capital-gain    [-99.999, 4999.95, 14999.85, 94999.05, 9999.9,...
# capital-loss    [-4.356, 1742.4, 1524.6, 1960.2, 2178.0, 1306....
# hours-per-week  [35.3, 45.1, 40.2, 30.4, 15.7, 59.8, 25.5, 20....
# native-country                                                  0
# income                                            [ <=50K,  >50K]
#
#                                                      value counts  \
# column
# ID              [1120, 1114, 1111, 1101, 1098, 1098, 1093, 109...
# age             [812, 803, 803, 794, 791, 790, 773, 773, 772, ...
# workclass          [13426, 1468, 1250, 1090, 762, 667, 586, 8, 5]
# fnlwgt          [8379, 6399, 3447, 3375, 1996, 872, 287, 113, ...
# education       [7195, 4914, 3638, 1185, 939, 790, 724, 619, 4...
# education-num   [9203, 6380, 4682, 1521, 1212, 1029, 926, 817,...
# marital-status             [11715, 8381, 3450, 808, 792, 323, 22]
# occupation      [2374, 2368, 2343, 2184, 2136, 1845, 1141, 104...
# relationship                 [10173, 6343, 3874, 2667, 1202, 771]
# race                                 [25125, 2826, 948, 282, 246]
# sex                                                 [12346, 6070]
# capital-gain    [21769, 615, 263, 111, 99, 34, 30, 2, 0, 0, 0,...
# capital-loss    [16797, 251, 201, 165, 69, 58, 45, 10, 8, 4, 4...
# hours-per-week  [15894, 3449, 2408, 1612, 1532, 1499, 1282, 99...
# native-country                                                  0
# income                                              [13649, 4386]
#
#                 histogram size   missing
# column
# ID                        20.0  0.335432
# age                       73.0  0.098676
# workclass                  9.0  0.408433
# fnlwgt                    20.0  0.232395
# education                 16.0  0.319646
# education-num             16.0  0.124321
# marital-status             7.0  0.217131
# occupation                15.0  0.424741
# relationship               6.0  0.231289
# race                       5.0  0.096250
# sex                        2.0  0.434415
# capital-gain              20.0  0.295998
# capital-loss              20.0  0.458862
# hours-per-week            20.0  0.013206
# native-country             0.0  0.008507
# income                     2.0  0.446117

# %% [markdown]
# ##### Step 3: save the dataset description

# %%
describer.dataset_description.to_csv(dataset_description_file)

# %% [markdown]
# ### Generate synthetic data
#
# ##### Step 4: Initialize a SyntheticDataGenerator.

# %%
generator = DataGenerator()
# Out:
# Initialized a synthetic data generator.

# %% [markdown]
# ##### Step 5: Generate sysnthetic dataset
#
# By default, the data is sampled from the histograms in dataset description. But users can let some columns to sample uniformly in doamin of [min, max].
#
# > generator.generate_uniform_random_dataset(dataset_description_file, N=10) # will generate a totoally random dataset.
#
# Here the example is to generate 10 rows in synthetic datset, where "age" and "education" are sampled uniformly.

# %%
generator.generate_synthetic_dataset(dataset_description_file, N=10, uniform_columns={'age', 'education'})

# %% [markdown]
# ##### Step 6: Random missing
#
# Remove values of a given column randomly, e.g., removing 60% of age values.

# %%
generator.random_missing_on_column('age', 0.6)

# %%
generator.synthetic_dataset
# Out:
#       ID   age          workclass  fnlwgt     education  education-num  \
# 0   4065  48.0            Private  160190       HS-grad           16.0
# 1  24288   NaN            Private  227763       Masters           13.0
# 2  27102   NaN            Private  231896       5th-6th            4.0
# 3  10423  26.0            Private   78382       1st-4th           13.0
# 4  16241   NaN            Private  231779           9th           10.0
# 5    836  60.0            Private  296062          11th            9.0
# 6    381   NaN   Self-emp-not-inc  149888       1st-4th           13.0
# 7  20011   NaN            Private  145245    Assoc-acdm           14.0
# 8    305   NaN            Private   87477   Prof-school           10.0
# 9  21814  23.0            Private  157218    Assoc-acdm           13.0
#
#         marital-status          occupation     relationship  \
# 0        Never-married    Transport-moving          Husband
# 1   Married-civ-spouse    Transport-moving        Own-child
# 2   Married-civ-spouse       Other-service    Not-in-family
# 3        Never-married                   ?        Unmarried
# 4             Divorced     Exec-managerial   Other-relative
# 5   Married-civ-spouse   Machine-op-inspct          Husband
# 6        Never-married   Handlers-cleaners    Not-in-family
# 7        Never-married        Craft-repair          Husband
# 8   Married-civ-spouse     Exec-managerial        Own-child
# 9        Never-married   Machine-op-inspct   Other-relative
#
#                   race      sex  capital-gain  capital-loss  hours-per-week  \
# 0                Black     Male           379            14              35
# 1                White     Male           344            56              35
# 2                White     Male            33            23              35
# 3   Asian-Pac-Islander     Male           345             6              34
# 4                White     Male         15110             3              39
# 5                White     Male            20             7              15
# 6                White   Female            46             1              54
# 7                Black     Male           245             4              39
# 8                White     Male           679          1754              35
# 9                White     Male           359             9              32
#
#                native-country  income
# 0             fRddDTdaMUweLKM   <=50K
# 1                        Aowy   <=50K
# 2                rptKdaHMGcLk   <=50K
# 3             qqDoCBKmcYWQkdK   <=50K
# 4  hObNPggEZuxcBEXlnTOpQIuOBL   <=50K
# 5                  QzWQIDsKXA    >50K
# 6          vvwKLlLYlXVXRLubVw   <=50K
# 7           okRSXjsqCjcxZzqez    >50K
# 8          ypAWuCwLXnTNhitTsz   <=50K
# 9   CDIIdNNcEqOLwFSkObyzkUWax   <=50K

# %% [markdown]
# ##### Step 7: Save the synthetic dataset

# %%
generator.synthetic_dataset.to_csv(synthetic_data_file, index=False)
